# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('quikr_car (1).csv')

# %%
data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
data.shape
# Out:
# (892, 6)

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
data['fuel_type'].value_counts()
# Out:
# Petrol    440
# Diesel    395
# LPG         2
# Name: fuel_type, dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
data.shape
# Out:
# (837, 6)

# %%
data.dtypes
# Out:
# name          object
# company       object
# year          object
# Price         object
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
data['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
data['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
data['Price'].replace('Ask For Price',np.nan,inplace=True)

# %%
data.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price         21
# kms_driven     0
# fuel_type      0
# dtype: int64

# %%
data['Price'].value_counts()
# Out:
# 2,50,000     16
# 3,50,000     12
# 4,00,000     11
# 1,30,000     11
# 2,10,000     10
#              ..
# 7,49,999      1
# 11,30,000     1
# 10,74,999     1
# 3,24,999      1
# 5,00,001      1
# Name: Price, Length: 272, dtype: int64

# %%
data['Price']=data['Price'].str.replace(',','')

# %%
data['Price'].value_counts()
# Out:
# 250000     16
# 350000     12
# 400000     11
# 130000     11
# 210000     10
#            ..
# 749999      1
# 1130000     1
# 1074999     1
# 324999      1
# 500001      1
# Name: Price, Length: 272, dtype: int64

# %%
data['Price']=data['Price'].astype(float)

# %%
data.dtypes
# Out:
# name           object
# company        object
# year           object
# Price         float64
# kms_driven     object
# fuel_type      object
# dtype: object

# %%
data.head()
# Out:
#                                      name   company  year     Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000.0
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018       NaN
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000.0
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data['Price'].fillna(data['Price'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000.000000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000.000000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  411717.615196
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000.000000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000.000000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data['Price']=data['Price'].astype(int)

# %%
data.dtypes
# Out:
# name          object
# company       object
# year          object
# Price          int64
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
data.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000  45,000 kms
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000      40 kms
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  411717  22,000 kms
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000  28,000 kms
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000  36,000 kms
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %%
data['kms_driven']=data['kms_driven'].str.replace('kms','')
data['kms_driven']=data['kms_driven'].str.replace(',','')
data['kms_driven']=data['kms_driven'].astype(int)

# %%
data.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000       45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000          40
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  411717       22000
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000       28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000       36000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %%
data.dtypes
# Out:
# name          object
# company       object
# year          object
# Price          int64
# kms_driven     int64
# fuel_type     object
# dtype: object

# %%
data['fuel_type'].value_counts()
# Out:
# Petrol    440
# Diesel    395
# LPG         2
# Name: fuel_type, dtype: int64

# %%
index=data[data['fuel_type']=='LPG'].index
index
# Out:
# Int64Index([482, 621], dtype='int64')

# %%
data.drop(index,inplace=True)

# %%
data.shape
# Out:
# (835, 6)

# %%
data['fuel_type'].value_counts()
# Out:
# Petrol    440
# Diesel    395
# Name: fuel_type, dtype: int64

# %%
data.reset_index(inplace=True,drop=True)

# %%
data.tail()
# Out:
#                            name   company  year   Price  kms_driven fuel_type
# 830  Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000       50000    Petrol
# 831   Tata Indica V2 DLE BS III      Tata  2009  110000       30000    Diesel
# 832        Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 833         Tata Zest XM Diesel      Tata  2018  260000       27000    Diesel
# 834          Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel

# %%
data.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000       45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000          40
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  411717       22000
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000       28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000       36000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %%
data['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel'], dtype=object)

# %%
data.dtypes
# Out:
# name          object
# company       object
# year          object
# Price          int64
# kms_driven     int64
# fuel_type     object
# dtype: object

# %%
data.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000       45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000          40
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  411717       22000
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000       28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000       36000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %%
sns.boxplot(data['Price'])
# Out:
# <Axes: >

# %%
data['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
data['year']=data['year'].astype(int)

# %%
data.dtypes
# Out:
# name          object
# company       object
# year           int64
# Price          int64
# kms_driven     int64
# fuel_type     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835 entries, 0 to 834
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        835 non-null    object
#  1   company     835 non-null    object
#  2   year        835 non-null    int64
#  3   Price       835 non-null    int64
#  4   kms_driven  835 non-null    int64
#  5   fuel_type   835 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 39.3+ KB

# %%
data['name']=data['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
data=data[data['Price']<3e6]

# %%
data.reset_index(drop=True)
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2        Maruti Suzuki Alto    Maruti  2018  411717       22000    Petrol
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 828      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 829          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 830    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 831            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 832      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [833 rows x 6 columns]

# %%
sns.boxplot(data['Price'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['kms_driven'])
# Out:
# <Axes: >

# %%
data=data[data['kms_driven']<3e5]

# %%
data.reset_index(drop=True)
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2        Maruti Suzuki Alto    Maruti  2018  411717       22000    Petrol
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 827      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 828          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 829    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 830            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 831      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [832 rows x 6 columns]

# %%
data['year'].value_counts()
# Out:
# 2015    116
# 2013     93
# 2014     91
# 2016     76
# 2012     74
# 2011     60
# 2009     55
# 2017     54
# 2010     43
# 2018     34
# 2006     22
# 2019     22
# 2007     19
# 2008     16
# 2005     13
# 2003     13
# 2004     12
# 2000      7
# 2002      5
# 2001      5
# 1995      2
# Name: year, dtype: int64

# %%
data.to_csv('cleaned_data.csv')

# %%
X=data.drop(columns='Price')
y=data['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=244)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# numerical_columns = ['year','kms_driven']
# categorical_columns = ['name','company','fuel_type']

# %%
# scaler = StandardScaler()

# %%
encoder = OneHotEncoder()
encoded_data = encoder.fit_transform(X[['name','company','fuel_type']])

# %%
# data[numerical_columns]=scaler.fit_transform(data[numerical_columns])

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=encoder.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# %%
model = LinearRegression()

# %%
pipe=make_pipeline(column_trans,model)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0', 'Audi A8',
#        'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y_pred=pipe.predict(X_test)
y_pred
# Out:
# array([ 452698.15025186,  303167.07448956, 2145077.61851727,
#         295747.55699229,  273767.86886788,  291331.47991916,
#         549021.40647696,  254546.74279491,  480755.57778863,
#        1273181.64306908,  225370.24398464,  237351.99951596,
#         445022.39213519,  259675.34567629,  301736.75574484,
#         495958.11007575,  266122.46488889,  247859.43810271,
#         339305.53106108,  501050.66627551,  366640.73429795,
#          17469.95234023,  403121.44725499,  559243.15068227,
#         311594.78071185,   42785.00393187,   70464.81730316,
#         259578.94262799,  470478.49093506,  383053.08500671,
#         118292.42876157,  547236.88953742,  381946.59926014,
#         131722.21249965, 1055589.64345795,  533568.84564437,
#         331664.66824973, 2145077.61851727,  809222.81829804,
#          17469.95234023,  380271.62551629,  291331.47991916,
#         374289.78571602,  161261.92241301,  456847.00346205,
# ...

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8409870624020204

# %%
result=pipe.predict(pd.DataFrame([['Maruti Suzuki Alto','Maruti',2019,100,'Petrol']],columns=['name','company','year','kms_driven','fuel_type']))
print(result)
# Out:
# [371725.80033989]

# %%
import pickle

# %%
pickle.dump(pipe,open('linearregressionmodel.pkl','wb'))
